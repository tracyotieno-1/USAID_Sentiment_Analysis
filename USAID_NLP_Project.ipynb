# %% [markdown]
# # USAID Sentiment Analysis

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import re
from collections import Counter
from wordcloud import WordCloud

import string
from string import punctuation
from textblob import TextBlob

from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, confusion_matrix, f1_score
from tqdm import tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Data Staging

# %%
# Load the 2 csv files we will be using 
df = pd.read_csv("usaid_reddit_posts_New.csv", encoding='latin1')
past_usaid_df = pd.read_csv("us_foreign_aid.csv", low_memory=False)

# %% [markdown]
# ##  Data Understanding for past USAID data

# %%
# Find the number of rows and columns 
past_usaid_df.shape
# Out:
# (950543, 48)

# %%
#Get description for each column
past_usaid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950543 entries, 0 to 950542
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   country_id                   950543 non-null  int64
#  1   country_code                 950257 non-null  object
#  2   country_name                 950543 non-null  object
#  3   region_id                    950543 non-null  int64
#  4   region_name                  950543 non-null  object
#  5   income_group_id              765594 non-null  float64
#  6   income_group_name            765594 non-null  object
#  7   income_group_acronym         765594 non-null  object
#  8   implementing_agency_id       950543 non-null  int64
#  9   implementing_agency_acronym  949844 non-null  object
#  10  implementing_agency_name     950543 non-null  object
#  11  implementing_subagency_id    950543 non-null  int64
#  12  subagency_acronym            855631 non-null  object
#  13  subagency_name               950543 non-null  object
#  14  channel_category_id          950539 non-null  float64
#  15  channel_category_name        950539 non-null  object
#  16  channel_subcategory_id       950539 non-null  float64
#  17  channel_subcategory_name     950539 non-null  object
#  18  channel_id                   950543 non-null  int64
#  19  channel_name                 950539 non-null  object
#  20  dac_category_id              950543 non-null  int64
#  21  dac_category_name            950543 non-null  object
#  22  dac_sector_code              950543 non-null  int64
#  23  dac_sector_name              950543 non-null  object
#  24  dac_purpose_code             950543 non-null  int64
#  25  dac_purpose_name             950543 non-null  object
#  26  funding_account_id           950543 non-null  object
#  27  funding_account_name         950543 non-null  object
#  28  funding_agency_id            950543 non-null  int64
#  29  funding_agency_name          950543 non-null  object
#  30  funding_agency_acronym       949636 non-null  object
#  31  assistance_category_id       950543 non-null  int64
#  32  assistance_category_name     950543 non-null  object
#  33  aid_type_group_id            950543 non-null  int64
#  34  aid_type_group_name          950543 non-null  object
#  35  activity_id                  950543 non-null  int64
#  36  activity_name                950377 non-null  object
#  37  activity_project_number      734258 non-null  object
#  38  activity_start_date          197996 non-null  object
#  39  activity_end_date            192289 non-null  object
#  40  transaction_type_id          950543 non-null  int64
#  41  transaction_type_name        950543 non-null  object
#  42  fiscal_year                  950543 non-null  object
#  43  current_amount               950543 non-null  int64
#  44  constant_amount              950543 non-null  int64
#  45  USG_sector_id                950543 non-null  int64
#  46  USG_sector_name              950543 non-null  object
#  47  submission_id                950543 non-null  int64
# dtypes: float64(3), int64(17), object(28)
# memory usage: 348.1+ MB

# %%
# Check duplicated rows
past_usaid_df.duplicated().sum()
# Out:
# 161

# %%
# Drop duplicated rows
past_usaid_df.drop_duplicates(inplace=True)

# %%
# Drop rows with missing values
past_usaid_df.dropna(inplace=True)

# %% [markdown]
# ## Explanatory Data Analysis for past USAID data

# %% [markdown]
# #### Line Chart Showing USAID Funding Trend Over Time

# %%
# Convert 'fiscal_year' to datetime if necessary
past_usaid_df['fiscal_year'] = pd.to_datetime(past_usaid_df['fiscal_year'], format='%Y')

# Aggregate funding by fiscal year
funding_over_time = past_usaid_df.groupby('fiscal_year')['current_amount'].sum().reset_index()

# Plot funding over time
plt.figure(figsize=(10, 6))
sns.lineplot(data=funding_over_time, x='fiscal_year', y='current_amount', marker='o')
plt.title('USAID Funding Over Time')
plt.xlabel('fiscal_year')
plt.ylabel('Total Funding (USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# The line chart above illustrates a trend showing USAID funding over time, there was a slow increase between 2002 and 2006, followed by a sharp rise between 2006 and 2012, suggesting a period of rapid growth.It reached a peak before stabilizing with minor fluctuations followed by a significant drop, indicating a sudden decline in funding.

# %% [markdown]
# #### Bar Plot Showing USAID Funding by Sector

# %%
# Aggregate funding by sector
funding_by_sector = past_usaid_df.groupby('dac_sector_name')['current_amount'].sum().reset_index()

# Sort by funding amount
funding_by_sector = funding_by_sector.sort_values(by='current_amount', ascending=False)

# Plot funding by sector
plt.figure(figsize=(12, 6))
sns.barplot(data=funding_by_sector, x='current_amount', y='dac_sector_name',  hue='dac_sector_name', palette='viridis')
plt.title('USAID Funding by Sector')
plt.xlabel('Total Funding (USD)')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# The bar plot shows that the most funded sectors by USAID are HIV/AIDS, Government and Civil Society, Emergency Response, Agriculture, and Basic Health. A withdrawal of USAID funding could significantly impact these sectors.

# %% [markdown]
# #### Bar Plot Showing the Top Receipient Countries of USAID Funding

# %%
# Aggregate funding by country
funding_by_country = past_usaid_df.groupby('country_name')['current_amount'].sum().reset_index()

# Sort and select top 10 countries
top_countries = funding_by_country.sort_values(by='current_amount', ascending=False).head(10)

# Plot top recipient countries
plt.figure(figsize=(10, 6))
sns.barplot(data=top_countries, x='current_amount', y='country_name', hue='country_name', palette='magma')
plt.title('Top 10 Recipient Countries of USAID Funding')
plt.xlabel('Total Funding (USD)')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# The bar graph shows that Afghanistan, Pakistan, Jordan, Kenya, and Iraq are the top recipients of USAID funding. A reduction or withdrawal of this funding could significantly impact their economies.

# %% [markdown]
# ## Reddit Data

# %% [markdown]
# ## Data Understanding for Reddit Data

# %%
# Merge the 'Text', 'title', and 'comments' columns into a new column called 'merged text'
df['merged text'] = df[['Text', 'title', 'comments']].apply(lambda x: ' '.join(x.dropna()), axis=1)

# %%
df.shape
# Out:
# (1299, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1299 entries, 0 to 1298
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Post ID             1299 non-null   object
#  1   region              1299 non-null   object
#  2   Text                1018 non-null   object
#  3   title               1298 non-null   object
#  4   Author              1298 non-null   object
#  5   subreddit           1298 non-null   object
#  6   score               1298 non-null   object
#  7   Upvote Ratio        1298 non-null   object
#  8   Number of Comments  1298 non-null   object
#  9   Created At          1298 non-null   object
#  10  url                 1298 non-null   object
#  11  Created Timestamp   1297 non-null   object
#  12  comments            800 non-null    object
#  13  Unnamed: 13         1 non-null      object
#  14  merged text         1299 non-null   object
# dtypes: object(15)
# memory usage: 152.4+ KB

# %%
df.columns
# Out:
# Index(['Post ID', 'region', 'Text', 'title', 'Author', 'subreddit', 'score',
#        'Upvote Ratio', 'Number of Comments', 'Created At', 'url',
#        'Created Timestamp', 'comments', 'Unnamed: 13', 'merged text'],
#       dtype='object')

# %%
df = df.drop(columns = ['Post ID', 'Text', 'title', 'Author', 'subreddit', 'score',
'Created At', 'url','Created Timestamp', 'comments', 'Unnamed: 13'])
df.head()
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
#
#                                          merged text
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...

# %%
df.isnull().sum()
# Out:
# region                0
# Upvote Ratio          1
# Number of Comments    1
# merged text           0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum(), df.shape
# Out:
# (region                0
#  Upvote Ratio          0
#  Number of Comments    0
#  merged text           0
#  dtype: int64,
#  (1298, 4))

# %%
df.duplicated().sum()
# Out:
# 14

# %%
# Identify and display duplicated rows
duplicated_rows = df[df.duplicated()]
duplicated_rows.head()
# Out:
#           region Upvote Ratio Number of Comments  \
# 52        Africa            1                  0
# 54        Africa            1                  0
# 243  Middle East            1                  0
# 248  Middle East            1                  0
# 249  Middle East            1                  0
#
#                                            merged text
# 52   [Politics] - How Donald Trump's USAID pause th...
# 54   [Politics] - How Donald Trump's USAID pause th...
# 243  Trump proposes taking over the Gaza strip, bui...
# 248  Trump proposes taking over the Gaza strip, bui...
# 249  Trump proposes taking over the Gaza strip, bui...

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1284, 4)

# %% [markdown]
# ## Sentiment Preprocessing

# %% [markdown]
# ### Removing Tags

# %%
def remove_tags(raw_text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', str(raw_text))
    return cleaned_text

# %%
df['cleaned_text'] = df['merged text'].apply(remove_tags)

# %%
df.head()
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...
#
#                                         cleaned_text
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...

# %% [markdown]
# ### Removing URLS

# %%
def remove_urls(text):
    pattern = re.compile(r'https?://\S+|www\.\S+|http?://\S+')
    return pattern.sub(r'', text)

# %%
df['cleaned_text'] = df['cleaned_text'].apply(remove_urls)

# %%
df.head()
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...
#
#                                         cleaned_text
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source:  Some people say that USAIDâs aid is...

# %% [markdown]
# ### Removing Unecessary Characters

# %%
def remove_unnecessary_characters(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', str(text))
    text = re.sub(r'\s+', ' ', str(text)).strip()
    return text

# %%
df['cleaned_text'] = df['cleaned_text'].apply(remove_unnecessary_characters)

# %%
df.head()
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...
#
#                                         cleaned_text
# 0  The Real Reason Musk is After USAID They Helpe...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money 79 ...
# 3  Heres my list of exposed corrupt money launder...
# 4  Source Some people say that USAIDs aid is excl...

# %% [markdown]
# ### Making all the Text in Lower case

# %%
df['cleaned_text'] = df['cleaned_text'].apply(lambda x:str(x).lower())

# %%
df.head(3)
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
#
#                                         cleaned_text
# 0  the real reason musk is after usaid they helpe...
# 1  usaid delivering foreign aid to starving child...
# 2  how usaid has been spending taxpayer money 79 ...

# %%
exclude = string.punctuation
exclude

def remove_punc1(text):
    return text.translate(str.maketrans('', '', exclude))

# %%
df['cleaned_text'] = df['cleaned_text'].apply(remove_punc1)

# %%
df.head()
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...
#
#                                         cleaned_text
# 0  the real reason musk is after usaid they helpe...
# 1  usaid delivering foreign aid to starving child...
# 2  how usaid has been spending taxpayer money 79 ...
# 3  heres my list of exposed corrupt money launder...
# 4  source some people say that usaids aid is excl...

# %% [markdown]
# ### Removing Stepwords From Dataset

# %%
sw_list = stopwords.words('english')

df['cleaned_text'] = df['cleaned_text'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))

# %%
df.head()
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...
#
#                                         cleaned_text
# 0  real reason musk usaid helped end apartheid so...
# 1  usaid delivering foreign aid starving children...
# 2  usaid spending taxpayer money 79 million teach...
# 3  heres list exposed corrupt money laundering fu...
# 4  source people say usaids aid exclusively human...

# %% [markdown]
# ### Normalizing the Dataset

# %%
def normalize_text(text):
    if isinstance(text, str):
        text = re.sub(r'[^\w\s]', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
    else:
        text = str(text)
    return text
df['cleaned_text'] = df['cleaned_text'].apply(normalize_text)

# %%
df.head()
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...
#
#                                         cleaned_text
# 0  real reason musk usaid helped end apartheid so...
# 1  usaid delivering foreign aid starving children...
# 2  usaid spending taxpayer money 79 million teach...
# 3  heres list exposed corrupt money laundering fu...
# 4  source people say usaids aid exclusively human...

# %% [markdown]
# ### Sentence Polarity

# %%
def checkPostiveOrNegativeSentence(sentence):
    text = sentence.strip().lower()
    sentiment = TextBlob(text).sentiment
    if sentiment.polarity > 0:
        return "Positive 😊"
    elif sentiment.polarity < 0:
        return "Negative 😠"
    else:
        return "Neutral 😐"

# %%
df['Sentiment'] = df['cleaned_text'].apply(checkPostiveOrNegativeSentence)

# %%
df.head(10)
# Out:
#    region Upvote Ratio Number of Comments  \
# 0  Africa         0.99                 21
# 1  Africa            1                  0
# 2  Africa         0.75                 33
# 3  Africa         0.99                 23
# 4  Africa         0.98                 12
# 5  Africa         0.86                629
# 6  Africa         0.71                236
# 7  Africa         0.91                  1
# 8  Africa            1                  0
# 9  Africa            1                  0
#
#                                          merged text  \
# 0  The Real Reason Musk is After USAID: They Help...
# 1  Usaid Delivering Foreign Aid to starving child...
# 2  How USAid has been spending taxpayer money\n\n...
# 3  Here's my list of exposed corrupt money launde...
# 4  Source: https://x.com/kenklippenstein/status/1...
# 5  âThe total closure of USAID would cause irre...
# 6  I'm not a federal employee but I'd like to hea...
# 7  \n\nThe second Trump administration is waging ...
# 8  [World] - 'People are going to die': USAID cut...
# 9  [World] - 'People are going to die': USAID cut...
#
#                                         cleaned_text   Sentiment
# 0  real reason musk usaid helped end apartheid so...  Positive 😊
# 1  usaid delivering foreign aid starving children...  Negative 😠
# 2  usaid spending taxpayer money 79 million teach...  Positive 😊
# 3  heres list exposed corrupt money laundering fu...  Negative 😠
# 4  source people say usaids aid exclusively human...  Positive 😊
# 5  total closure usaid would cause irreparable da...  Positive 😊
# 6  im federal employee id like hear comments rega...  Positive 😊
# 7  second trump administration waging aggressive ...  Positive 😊
# 8  world people going die usaid cuts create panic...   Neutral 😐
# 9  world people going die usaid cuts create panic...   Neutral 😐

# %%
df.shape
# Out:
# (1284, 6)

# %% [markdown]
# ## EDA

# %%
# Perform Exploratory Data Analysis (EDA)
def perform_eda(data):
    # Check class distribution
    print("Class distribution:")
    print(df['Sentiment'].value_counts())

    # Text length analysis
    df['text_length'] = df['cleaned_text'].apply(len)
    print("\nText length stats:")
    print(df['text_length'].describe())

    # Visualize class distribution
    df['Sentiment'].value_counts().plot(kind='bar', title="Class Distribution")
    plt.show()
perform_eda(df)
# Out:
# Class distribution:
# Sentiment
# Positive 😊    998
# Negative 😠    187
# Neutral 😐      99
# Name: count, dtype: int64
#
# Text length stats:
# count     1284.000000
# mean      4155.781153
# std       5483.444872
# min          0.000000
# 25%        456.750000
# 50%       1776.500000
# 75%       5162.250000
# max      41026.000000
# Name: text_length, dtype: float64

# %%
# Combine all texts based on sentiment
positive_text = df[df['Sentiment'] == 'Positive 😊']['cleaned_text'].str.cat(sep=' ')
negative_text = df[df['Sentiment'] == 'Negative 😠']['cleaned_text'].str.cat(sep=' ')
neutral_text = df[df['Sentiment'] == 'Neutral 😐']['cleaned_text'].str.cat(sep=' ')

# %%
# Function to get the most common words
def get_common_words(text):
    words = text.split()
    return Counter(words).most_common(10)

# %%
# Extract most common words
positive_common_words = get_common_words(positive_text)
negative_common_words = get_common_words(negative_text)
neutral_common_words = get_common_words(neutral_text)

print("Positive Common Words:", positive_common_words)
print("Negative Common Words:", negative_common_words)
print("Neutral Common Words:", neutral_common_words)
# Out:
# Positive Common Words: [('us', 3720), ('market', 2479), ('also', 2366), ('one', 2001), ('armenia', 1955), ('new', 1847), ('would', 1656), ('international', 1652), ('government', 1618), ('people', 1608)]
# Negative Common Words: [('de', 335), ('us', 327), ('la', 198), ('que', 198), ('people', 184), ('said', 179), ('war', 167), ('like', 165), ('ukraine', 164), ('trump', 152)]
# Neutral Common Words: [('usaid', 55), ('america', 23), ('asia', 19), ('east', 17), ('world', 16), ('africa', 16), ('south', 16), ('middle', 16), ('rworldnews', 12), ('us', 12)]

# %%
# Function to create WordCloud
def plot_wordcloud(text, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title, fontsize=16)
    plt.show()

# Generate WordClouds for each sentiment
plot_wordcloud(positive_text, 'Positive Sentiment WordCloud')
print("*" * 93)
plot_wordcloud(negative_text, 'Negative Sentiment WordCloud')
print("*" * 93)
plot_wordcloud(neutral_text, 'Neutral Sentiment WordCloud')
# Out:
# *********************************************************************************************
# *********************************************************************************************

# %% [markdown]
# 1. `Positive Sentiment WordCloud`
#
# - *Main Themes:* Words like Armenia, Russia, USAID, and people dominate the word cloud, suggesting that these topics were often mentioned positively.
# - *Key Observations:* Positive contributions by USAID or international efforts involving countries like Armenia and Russia. Positive sentiment reflects optimism around government initiatives or partnerships.
#
# 2. `Negative Sentiment WordCloud`
# - *Main Themes:* Words like Ukraine, US, Russia, Trump, people, and war are prominent, indicating a focus on conflict, dissatisfaction, or controversy.
# - *Key Observations:* Negative discussions center on USAID's involvement in contentious regions, war-related topics, and public criticism of specific policies. Terms like Trump and military suggest negative views on leadership decisions and USAID withdrawal.
#
# 3. `Neutral Sentiment WordCloud`
# - *Main Themes:* Words like world, USAID, Africa, and Middle East appear frequently, suggesting that neutral discussions revolve around general information or broad topics.
# - *Key Observations:* Neutral sentiment represents factual reporting or balanced discussions about USAID’s role in various regions and sectors. Topics such as trade, digital, and energy hint at broader global or economic implications.

# %%
df1 = df.copy()

# %%
df.to_csv("cleaned_data.csv", index=False)

# %% [markdown]
# ## Model Building

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Assuming your dataset has 'cleaned_text' and 'Sentiment' columns
X = df['cleaned_text']
y = df['Sentiment']

# Encode the labels (Positive, Negative -> 1, 0)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# Convert training text to numerical features (e.g., TF-IDF)
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)

# Visualize class distribution before resampling
def plot_class_distribution(y_data, title, labels):
    counts = Counter(y_data)
    plt.figure(figsize=(6, 4))
    plt.bar(counts.keys(), counts.values(), color=['skyblue', 'orange'])
    plt.xticks(ticks=range(len(labels)), labels=labels)
    plt.title(title)
    plt.xlabel('Classes')
    plt.ylabel('Frequency')
    plt.show()

# Plot before resampling
plot_class_distribution(y_train, "Class Distribution Before Resampling", labels=label_encoder.classes_)

# Apply SMOTE to balance the training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_tfidf, y_train)

# Plot after resampling
plot_class_distribution(y_train_resampled, "Class Distribution After Resampling", labels=label_encoder.classes_)

# Transform the test set using the same TF-IDF vectorizer
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
X_train_tfidf.shape
# Out:
# (1027, 5000)

# %% [markdown]
# ### Model Building

# %% [markdown]
# ### LSTM

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Custom Dataset for TF-IDF features
class TfidfDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return self.features.shape[0]

    def __getitem__(self, idx):
        feature = torch.FloatTensor(self.features[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)  # Return the label directly
        return feature, label

# %%
# Create dataset objects
train_dataset = TfidfDataset(X_train_resampled.toarray(), y_train_resampled)
test_dataset = TfidfDataset(X_test_tfidf.toarray(), y_test)

# DataLoader for batching the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Define LSTM model with dropout for regularization
class LSTMClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout_rate=0.3):
        super(LSTMClassifier, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # LSTM Layer with dropout
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_rate)

        # Fully Connected Layer
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))

        # Apply dropout to the last hidden state
        out = self.dropout(out[:, -1, :])

        # Decode the hidden state of the last time step
        out = self.fc(out)
        return out

# Hyperparameters
input_size = X_train_resampled.shape[1]  # Number of TF-IDF features
hidden_size = 256
num_layers = 2
num_classes = 3  # Assuming binary sentiment classification
dropout_rate = 0.3

# Instantiate the model
model_lstm = LSTMClassifier(input_size, hidden_size, num_layers, num_classes, dropout_rate).to(device)

# Loss, optimizer, and learning rate scheduler
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model_lstm.parameters(), lr=0.001, weight_decay=1e-4)  # AdamW with weight decay
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10)  # Learning Rate Scheduling

# %%
# Early stopping
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss == None:
            self.best_loss = val_loss
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

early_stopping = EarlyStopping(patience=3, min_delta=0.01)

# %%
# Training loop
epochs = 5
for epoch in range(epochs):
    model_lstm.train()
    epoch_loss = 0
    correct = 0
    total = 0

    loop = tqdm(train_loader, leave=True)
    for features, labels in loop:
        features, labels = features.to(device), labels.to(device).long()
        optimizer.zero_grad()

        # Forward pass
        outputs = model_lstm(features.unsqueeze(1))  # Add sequence dimension for LSTM
        loss = criterion(outputs, labels)
        epoch_loss += loss.item()

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        loop.set_description(f'Epoch {epoch + 1}')
        loop.set_postfix(loss=loss.item(), accuracy=100. * correct / total)

    # Validation
    model_lstm.eval()
    val_loss = 0
    with torch.no_grad():
        for features, labels in test_loader:  # Here we use test_loader as validation, adjust if you have a separate validation set
            features, labels = features.to(device), labels.to(device).long()
            outputs = model_lstm(features.unsqueeze(1))
            val_loss += criterion(outputs, labels).item()
    val_loss /= len(test_loader)

    # Learning Rate Scheduling
    scheduler.step(val_loss)

    # Early Stopping
    early_stopping(val_loss)
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# Epoch 1: 100%|██████████| 75/75 [00:24<00:00,  3.01it/s, accuracy=65.5, loss=0.147]
# Epoch 2: 100%|██████████| 75/75 [00:21<00:00,  3.48it/s, accuracy=96.1, loss=0.0604]
# Epoch 3: 100%|██████████| 75/75 [00:31<00:00,  2.41it/s, accuracy=99.1, loss=0.0112]
# Epoch 4: 100%|██████████| 75/75 [00:20<00:00,  3.69it/s, accuracy=99.6, loss=0.00201]
# Epoch 5: 100%|██████████| 75/75 [00:21<00:00,  3.43it/s, accuracy=99.7, loss=0.00297]
# Early stopping

# %%
# Evaluation (use your previous evaluation code here)
model_lstm.eval()
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for features, labels in test_loader:
        features = features.to(device)
        labels = labels.to(device).long()  # Ensure labels are in the correct format
        outputs = model_lstm(features.unsqueeze(1))
        probs = torch.nn.functional.softmax(outputs, dim=1)
        _, predicted = torch.max(outputs.data, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())  # Ensure this is a 1D tensor
        all_probs.extend(probs.cpu().numpy())  # Assuming class 1 is the positive class

# %%
# Metrics
accuracy = accuracy_score(all_labels, all_preds)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8521400778210116

# %%
f1 = f1_score(all_labels, all_preds, average='weighted')
print(f"F1 score : {f1}")
# Out:
# F1 score : 0.8355672017355409

# %%
# AUC Score
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr') 
print(f"AUC Score: {auc}")
# Out:
# AUC Score: 0.9393099758955854

# %%
# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=['Positive 😊', 'Negative 😠','Neutral 😐']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   Positive 😊       0.65      0.35      0.46        37
#   Negative 😠       0.76      0.65      0.70        20
#    Neutral 😐       0.88      0.96      0.92       200
#
#     accuracy                           0.85       257
#    macro avg       0.76      0.66      0.69       257
# weighted avg       0.84      0.85      0.84       257

# %% [markdown]
# ### CNN

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
from torch.optim.lr_scheduler import    ReduceLROnPlateau

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Custom Dataset for TF-IDF features
class TfidfDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return self.features.shape[0]

    def __getitem__(self, idx):
        feature = torch.FloatTensor(self.features[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)  
        return feature, label


# Create dataset objects
train_dataset = TfidfDataset(X_train_resampled.toarray(), y_train_resampled)
test_dataset = TfidfDataset(X_test_tfidf.toarray(), y_test)

# DataLoader for batching the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Define CNN model with dropout for regularization

class CNNClassifier(nn.Module):
    def __init__(self, input_size, num_classes, dropout_rate=0.3):
        super(CNNClassifier, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=input_size, out_channels=256, kernel_size=3,padding=1)
        self.conv2 = nn.Conv1d(in_channels=256, out_channels=128, kernel_size=3,padding=1)
        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, num_classes)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool1d(x, kernel_size=x.size(2))  # Global max pooling
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Hyperparameters
input_size = X_train_resampled.shape[1]  # Number of TF-IDF features
num_classes = 3  # Assuming binary sentiment classification
dropout_rate = 0.3

# Instantiate the model
model_cnn = CNNClassifier(input_size, num_classes, dropout_rate).to(device)

# Loss, optimizer, and learning rate scheduler
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model_cnn.parameters(), lr=0.001, weight_decay=1e-4)  # AdamW with weight decay
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10)  #

# Early stopping
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss == None:
            self.best_loss = val_loss
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

early_stopping = EarlyStopping(patience=3, min_delta=0.01)

# Training loop
epochs = 5

for epoch in range(epochs):
    model_cnn.train()
    epoch_loss = 0
    correct = 0
    total = 0

    loop = tqdm(train_loader, leave=True)
    for features, labels in loop:
        features, labels = features.to(device), labels.squeeze().to(device)

        # Forward pass
        outputs = model_cnn(features.unsqueeze(1).permute(0, 2, 1))  # Add channel dimension for CNN
        loss = criterion(outputs, labels)
        epoch_loss += loss.item()

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        loop.set_description(f'Epoch {epoch + 1}')
        loop.set_postfix(loss=loss.item(), accuracy=100. * correct / total)

    # Validation
    model_cnn.eval()
    val_loss = 0
    with torch.no_grad():
        for features, labels in test_loader:  # Here we use test_loader as validation, adjust if you have a separate validation set
            features, labels = features.to(device), labels.to(device).long()
            outputs = model_cnn(features.unsqueeze(1).permute(0, 2, 1))
            val_loss += criterion(outputs, labels).item()
    val_loss /= len(test_loader)


    
    # Learning Rate Scheduling
    scheduler.step(val_loss)

    # Early Stopping
    early_stopping(val_loss)
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# Using device: cpu
# Epoch 1: 100%|██████████| 75/75 [00:27<00:00,  2.72it/s, accuracy=70.1, loss=0.236]
# Epoch 2: 100%|██████████| 75/75 [00:28<00:00,  2.67it/s, accuracy=97.7, loss=0.125]
# Epoch 3: 100%|██████████| 75/75 [00:23<00:00,  3.19it/s, accuracy=99.6, loss=0.0434]
# Epoch 4: 100%|██████████| 75/75 [00:29<00:00,  2.56it/s, accuracy=99.5, loss=0.00129]
# Early stopping

# %%
# Evaluation
model_cnn.eval()
all_preds_cnn = []
all_labels_cnn = []
all_probs_cnn = []

with torch.no_grad():
    for features, labels in test_loader:
        features, labels = features.to(device), labels.to(device)  # No need to squeeze labels
        outputs = model_cnn(features.unsqueeze(1).permute(0, 2, 1))  # Add channel dimension
        probs = torch.nn.functional.softmax(outputs, dim=1)  # Softmax for probabilities
        _, predicted = torch.max(outputs.data, 1)  # Get predicted class indices

        all_preds_cnn.extend(predicted.cpu().numpy())  # Extend with batch predictions
        all_labels_cnn.extend(labels.cpu().numpy())  # Extend with batch labels
        all_probs_cnn.extend(probs.cpu().numpy())   # Assuming class 1 is the positive class

# %%
#accuracy
accuracy = accuracy_score(all_labels_cnn, all_preds_cnn)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8404669260700389

# %%
#f1 score
f1 = f1_score(all_labels_cnn, all_preds_cnn, average='weighted')
print(f"F1 score : {f1}")
# Out:
# F1 score : 0.8180301087144759

# %%
# Compute AUC for multiclass (One-vs-Rest strategy)
auc = roc_auc_score(all_labels_cnn, all_probs_cnn, multi_class='ovr')
print(f"AUC Score: {auc}")
# Out:
# AUC Score: 0.930861619599128

# %%
#confusion matrix
cm = confusion_matrix(all_labels_cnn, all_preds_cnn)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

#classifiaction report
print("Classification Report:")
print(classification_report(all_labels_cnn, all_preds_cnn, target_names=['Positive 😊', 'Negative 😠','Neutral 😐']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   Positive 😊       0.65      0.30      0.41        37
#   Negative 😠       0.73      0.55      0.63        20
#    Neutral 😐       0.86      0.97      0.91       200
#
#     accuracy                           0.84       257
#    macro avg       0.75      0.61      0.65       257
# weighted avg       0.82      0.84      0.82       257

# %%
import pandas as pd
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score

# %%
import torch

# Save the model
model_path = "lstm_sentiment_model.pth"
torch.save(model_lstm.state_dict(), model_path)

print(f"Model saved to {model_path}")
# Out:
# Model saved to lstm_sentiment_model.pth

# %%
import pickle

with open("tfidf_vectorizer.pkl", "wb") as vec_file:
    pickle.dump(tfidf_vectorizer, vec_file)

print("TF-IDF Vectorizer saved successfully!")
# Out:
# TF-IDF Vectorizer saved successfully!
